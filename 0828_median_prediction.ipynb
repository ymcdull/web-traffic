# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
k = pd.read_csv("key_1.csv", nrows=100)
sample = pd.read_csv("sample_submission_1.csv", nrows=100)
train = pd.read_csv("train_1.csv")

# %%
k.shape, sample.shape, train.shape
# Out:
# ((100, 2), (100, 2), (145063, 551))

# %%
k.head()
# Out:
#                                                 Page            Id
# 0  !vote_en.wikipedia.org_all-access_all-agents_2...  bf4edcf969af
# 1  !vote_en.wikipedia.org_all-access_all-agents_2...  929ed2bf52b9
# 2  !vote_en.wikipedia.org_all-access_all-agents_2...  ff29d0f51d5c
# 3  !vote_en.wikipedia.org_all-access_all-agents_2...  e98873359be6
# 4  !vote_en.wikipedia.org_all-access_all-agents_2...  fa012434263a

# %%
k.Page[1]
# Out:
# '!vote_en.wikipedia.org_all-access_all-agents_2017-01-02'

# %%
sample.head()
# Out:
#              Id  Visits
# 0  bf4edcf969af       0
# 1  929ed2bf52b9       0
# 2  ff29d0f51d5c       0
# 3  e98873359be6       0
# 4  fa012434263a       0

# %%
'!vote_en.wikipedia.org_all-access_all-agnets' in train.Page
# Out:
# False

# %%
pd.read_csv("../input/key_1.csv",converters={'Page':lamabda p:p[:-11]}, index_col='Page').join(pd.read_csv("../input/train_1.csv", usecols=[0]+list(range(502,551)), index_col='Page').median(axis=1,skipna=True).to_frame(name='Visits'), how='left').fillna(0).to_csv('sub.csv', float_format='%.0f', index=False)

# %%
k.Page.apply(lambda x: x[:-11]).unique()
# Out:
# array(['!vote_en.wikipedia.org_all-access_all-agents',
#        '!vote_en.wikipedia.org_all-access_spider'], dtype=object)

# %%
k = pd.read_csv("key_1.csv", converters={"Page": lambda p: p[:-11]}, index_col = "Page")

# %%
train = pd.read_csv("train_1.csv", usecols=[0] + list(range(502, 551)), index_col = "Page")

# %%
train.head()
# Out:
#                                                     2016-11-13  2016-11-14  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    8.0        15.0
# 2PM_zh.wikipedia.org_all-access_spider                    11.0        14.0
# 3C_zh.wikipedia.org_all-access_spider                      4.0         2.0
# 4minute_zh.wikipedia.org_all-access_spider                13.0        14.0
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        11.0         8.0
#
#                                                     2016-11-15  2016-11-16  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                   14.0        12.0
# 2PM_zh.wikipedia.org_all-access_spider                    28.0        23.0
# 3C_zh.wikipedia.org_all-access_spider                      4.0         6.0
# 4minute_zh.wikipedia.org_all-access_spider                17.0        26.0
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         6.0        10.0
#
# ...

# %%
train.shape
# Out:
# (100, 551)

# %%
train = train.median(axis = 1, skipna=True).to_frame(name="Visits")

# %%
k.join(train, how = 'left').fillna(0).to_csv("sub.csv", float_format = '%.0f', index = False)

# %%
train.head()
# Out:
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
# 1        15.0        18.0        11.0        13.0        22.0        11.0
# 2         1.0         1.0         0.0         4.0         0.0         3.0
# 3        10.0        94.0         4.0        26.0        14.0         9.0
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
train
# Out:
#                                                  Page  2015-07-01  2015-07-02  \
# 0             2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1              2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2               3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3          4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4   52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
# 5             5566_zh.wikipedia.org_all-access_spider        12.0         7.0
# 6           91Days_zh.wikipedia.org_all-access_spider         NaN         NaN
# 7            A'N'D_zh.wikipedia.org_all-access_spider       118.0        26.0
# 8            AKB48_zh.wikipedia.org_all-access_spider         5.0        23.0
# 9            ASCII_zh.wikipedia.org_all-access_spider         6.0         3.0
# 10           ASTRO_zh.wikipedia.org_all-access_spider         NaN         NaN
# ...

# %%
len(train.columns)
# Out:
# 551

# %%
aa=train.iloc[0, 1:].values

# %%
plt.plot(range(len(aa)), aa)
